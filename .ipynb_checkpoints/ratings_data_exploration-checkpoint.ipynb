# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
ratings_data = pd.read_csv("new_ratings_data_cleaned.csv", encoding='latin_1')
ratings_data.shape
# Out:
# (326, 126)

# %%
ratings_data.head()
# Out:
#    writer        cik                    company     date_created     platform  \
# 0  Olivia  1778006.0          Weeds Never Sleep   7/3/2019 11:08     TruCrowd
# 1  Olivia  1720258.0        StorEn Technologies    7/4/2019 8:55  StartEngine
# 2  Olivia  1753677.0  Palouse Ag-Drone Services  7/11/2019 14:41     Razitall
# 3  Olivia  1765620.0  El Tinieblo International  7/13/2019 10:14  StartEngine
# 4  Olivia  1777377.0                  Spero CBD  7/16/2019 10:34  StartEngine
#
#                                         platform_url  \
# 0  https://us.trucrowd.com/equity/offer-summary/W...
# 1    https://www.startengine.com/storen-technologies
# 2  https://www.razitall.com/pitch/the-ag-drone-an...
# 3  https://www.startengine.com/el-tinieblo-intern...
# 4              https://www.startengine.com/spero-cbd
#
#                                       sec_filing_url sec_filing_date  \
# 0  https://disclosurequest.com/form/weeds-never-s...       6/25/2019
# 1  https://www.sec.gov/Archives/edgar/data/172025...        7/3/2019
# 2  https://disclosurequest.com/form/palouse-ag-dr...       10/4/2018
# 3  https://www.sec.gov/Archives/edgar/data/176562...       7/12/2019
# 4  https://www.sec.gov/Archives/edgar/data/177737...       7/15/2019
#
#                          legal_name                          dba     ...       \
# 0             Weeds Never Sleep LLC  Weeds Never Sleep or HotZot     ...
# 1               StorEn Technologies          StorEn Technologies     ...
# 2     Palouse Ag-Drone Services LLC                 The Ag-Drone     ...
# 3  El Tinieblo International, Inc.     El Tinieblo International     ...
# 4                    Noble Naturals                    Spero CBD     ...
#
#   spacer founder 9 founder_9_relevant_industry_experience  \
# 0              NaN                                    NaN
# 1              NaN                                    NaN
# 2              NaN                                    NaN
# 3              NaN                                    NaN
# 4              NaN                                    NaN
#
#   founder_9_previous_startups founder_9_exits founder_9_age  \
# 0                         NaN             NaN           NaN
# 1                         NaN             NaN           NaN
# 2                         NaN             NaN           NaN
# 3                         NaN             NaN           NaN
# 4                         NaN             NaN           NaN
#
#   founder_9_graduated_from_top_100 Unnamed: 122  Unnamed: 123 Unnamed: 124  \
# 0                              NaN          NaN           NaN          NaN
# 1                              NaN          NaN           NaN          NaN
# 2                              NaN          NaN           NaN          NaN
# 3                              NaN          NaN           NaN          NaN
# 4                              NaN          NaN           NaN          NaN
#
#   Unnamed: 125
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 126 columns]

# %%
ratings_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Columns: 126 entries, writer to Unnamed: 125
# dtypes: float64(63), object(63)
# memory usage: 321.0+ KB

# %%
ratings_data.columns
# Out:
# Index(['writer', 'cik', 'company', 'date_created', 'platform', 'platform_url',
#        'sec_filing_url', 'sec_filing_date', 'legal_name', 'dba',
#        ...
#        'spacer founder 9', 'founder_9_relevant_industry_experience',
#        'founder_9_previous_startups', 'founder_9_exits', 'founder_9_age',
#        'founder_9_graduated_from_top_100', 'Unnamed: 122', 'Unnamed: 123',
#        'Unnamed: 124', 'Unnamed: 125'],
#       dtype='object', length=126)

# %%
ratings_data.describe()
# Out:
#                 cik  rev_share_return_multiple  valuations_combined  \
# count  3.140000e+02                  30.000000         2.750000e+02
# mean   1.766095e+06                   1.585000         9.417198e+06
# std    5.553635e+04                   0.398737         1.310159e+07
# min    1.398488e+06                   1.000000         0.000000e+00
# 25%    1.753142e+06                   1.300000         3.200000e+06
# 50%    1.787346e+06                   1.500000         5.600000e+06
# 75%    1.797639e+06                   1.750000         1.000000e+07
# max    1.808346e+06                   3.000000         1.200000e+08
#
#        market_size_total  market_size_addressable  total_revenue  \
# count       3.140000e+02             3.140000e+02   3.140000e+02
# mean        4.186561e+11             2.553118e+11   3.723411e+05
# std         2.229669e+12             2.113630e+12   1.315171e+06
# min         1.000000e+07             1.000000e+06   0.000000e+00
# 25%         9.914000e+09             1.000000e+09   0.000000e+00
# 50%         4.673000e+10             8.340000e+09   2.394000e+03
# 75%         1.855000e+11             3.168000e+10   1.835465e+05
# max         2.980000e+13             2.980000e+13   1.844223e+07
#
#         monthly_burn  monthly_burn_rate  relevant_partners    founders  \
# count     312.000000         314.000000         314.000000  314.000000
# mean    22163.352564           0.482779           4.968153    1.633758
# std     53835.701404           0.480289          35.585728    0.891712
# min         0.000000           0.000000           0.000000    1.000000
# 25%       262.750000           0.024450           0.000000    1.000000
# 50%      3735.500000           0.086700           0.000000    1.000000
# 75%     19204.250000           1.000000           1.000000    2.000000
# max    565876.000000           1.000000         500.000000    9.000000
#
#            ...       founder_8_age  founder_8_graduated_from_top_100  \
# count      ...                 1.0                               1.0
# mean       ...                 0.0                               0.0
# std        ...                 NaN                               NaN
# min        ...                 0.0                               0.0
# 25%        ...                 0.0                               0.0
# 50%        ...                 0.0                               0.0
# 75%        ...                 0.0                               0.0
# max        ...                 0.0                               0.0
#
#        spacer founder 9  founder_9_relevant_industry_experience  \
# count               1.0                                     1.0
# mean                0.0                                    49.0
# std                 NaN                                     NaN
# min                 0.0                                    49.0
# 25%                 0.0                                    49.0
# 50%                 0.0                                    49.0
# 75%                 0.0                                    49.0
# max                 0.0                                    49.0
#
#        founder_9_exits  founder_9_age  founder_9_graduated_from_top_100  \
# count              0.0            0.0                               1.0
# mean               NaN            NaN                              13.0
# std                NaN            NaN                               NaN
# min                NaN            NaN                              13.0
# 25%                NaN            NaN                              13.0
# 50%                NaN            NaN                              13.0
# 75%                NaN            NaN                              13.0
# max                NaN            NaN                              13.0
#
#        Unnamed: 122  Unnamed: 123  Unnamed: 124
# count           1.0           1.0           1.0
# mean            0.0           0.0          39.0
# std             NaN           NaN           NaN
# min             0.0           0.0          39.0
# 25%             0.0           0.0          39.0
# 50%             0.0           0.0          39.0
# 75%             0.0           0.0          39.0
# max             0.0           0.0          39.0
#
# [8 rows x 63 columns]

# %%
#pd.set_option("display.precision", 2)
#ratings_data.tail()

# %%
ratings_data.describe(include=np.object)
# Out:
#        writer  company    date_created     platform  \
# count     314      314             274          314
# unique      4      314             274           20
# top       Dan  Airemos  2/5/2020 16:40  StartEngine
# freq      151        1               1           78
#
#                                              platform_url  \
# count                                                 314
# unique                                                314
# top     https://app.honeycombcredit.com/en/projects/11...
# freq                                                    1
#
#                                            sec_filing_url sec_filing_date  \
# count                                                 314             314
# unique                                                314             144
# top     https://www.sec.gov/Archives/edgar/data/180077...       2/28/2020
# freq                                                    1              10
#
#                  legal_name                 dba          industry  \
# count                   314                 307               314
# unique                  314                 307                72
# top     Snake Oil Song, LLC  Stone's Throw Hash  Food & Beverages
# freq                      1                   1                38
#
#            ...      has_famous_founders founder_1_graduated_from_top_100  \
# count      ...                      314                              314
# unique     ...                        2                                2
# top        ...                       No                               No
# freq       ...                      303                              248
#
#        founder_2_graduated_from_top_100 founder_3_graduated_from_top_100  \
# count                               126                               32
# unique                                2                                2
# top                                  No                               No
# freq                                 94                               22
#
#        founder_4_graduated_from_top_100 founder_5_graduated_from_top_100  \
# count                                10                                2
# unique                                3                                1
# top                                  No                               No
# freq                                  5                                2
#
#        spacer founder 7 founder_8_relevant_industry_experience  \
# count                 1                                      1
# unique                1                                      1
# top                  No                                     No
# freq                  1                                      1
#
#        founder_9_previous_startups Unnamed: 125
# count                            1            1
# unique                           1            1
# top                             No           No
# freq                             1            1
#
# [4 rows x 63 columns]

# %%
pd.set_option("display.max.columns", None)

# %%
ratings_data.head()
# Out:
#    writer        cik                    company     date_created     platform  \
# 0  Olivia  1778006.0          Weeds Never Sleep   7/3/2019 11:08     TruCrowd
# 1  Olivia  1720258.0        StorEn Technologies    7/4/2019 8:55  StartEngine
# 2  Olivia  1753677.0  Palouse Ag-Drone Services  7/11/2019 14:41     Razitall
# 3  Olivia  1765620.0  El Tinieblo International  7/13/2019 10:14  StartEngine
# 4  Olivia  1777377.0                  Spero CBD  7/16/2019 10:34  StartEngine
#
#                                         platform_url  \
# 0  https://us.trucrowd.com/equity/offer-summary/W...
# 1    https://www.startengine.com/storen-technologies
# 2  https://www.razitall.com/pitch/the-ag-drone-an...
# 3  https://www.startengine.com/el-tinieblo-intern...
# 4              https://www.startengine.com/spero-cbd
#
#                                       sec_filing_url sec_filing_date  \
# 0  https://disclosurequest.com/form/weeds-never-s...       6/25/2019
# 1  https://www.sec.gov/Archives/edgar/data/172025...        7/3/2019
# 2  https://disclosurequest.com/form/palouse-ag-dr...       10/4/2018
# 3  https://www.sec.gov/Archives/edgar/data/176562...       7/12/2019
# 4  https://www.sec.gov/Archives/edgar/data/177737...       7/15/2019
#
#                          legal_name                          dba  \
# 0             Weeds Never Sleep LLC  Weeds Never Sleep or HotZot
# 1               StorEn Technologies          StorEn Technologies
# 2     Palouse Ag-Drone Services LLC                 The Ag-Drone
# 3  El Tinieblo International, Inc.     El Tinieblo International
# 4                    Noble Naturals                    Spero CBD
#
#            industry tech_sector  stage    series crowdfunding_type_1  \
# 0    Consumer Goods    AgriTech  Early  Pre-Seed               RegCF
# 1    Consumer Goods   CleanTech  Early  Pre-Seed               RegCF
# 2           Farming    AgriTech  Early  Pre-Seed               RegCF
# 3    Wine & Spirits    Non-Tech  Early  Pre-Seed               RegCF
# 4  Cannabis and CBD    Non-Tech  Early  Pre-Seed               RegCF
#
#   crowdfunding_type_2     security_type  rev_share_return_multiple  \
# 0                 NaN              SAFE                        NaN
# 1                 NaN   Equity - Common                        NaN
# 2                 NaN             CAFES                        NaN
# 3                 NaN   Equity - Common                        NaN
# 4                 NaN  Convertible Note                        NaN
#
#   debt_interest_rate pre_money_valuation valuation_cap discount_rate  \
# 0                NaN                 NaN   $2,500,000             0%
# 1                NaN        $28,100,000            NaN           NaN
# 2                NaN                 NaN     $400,000             0%
# 3                NaN         $7,500,000            NaN           NaN
# 4                NaN                 NaN   $6,000,000            20%
#
#   valuation_cap_after_discount  valuations_combined valuations_brackets  \
# 0                  $2,500,000             2500000.0              #NAME?
# 1                          NaN           28100000.0              #NAME?
# 2                    $400,000              400000.0              #NAME?
# 3                          NaN            7500000.0              #NAME?
# 4                  $4,800,000             4800000.0              #NAME?
#
#    revenue_model distrubution_model business_type has_scalable_business_model  \
# 0  Transactional                B2C    Life Style                          No
# 1  Transactional                B2C    Life Style                          No
# 2  Transactional                B2C    Life Style                          No
# 3  Transactional              B2B2C    Life Style                          No
# 4  Transactional                B2C    Life Style                         Yes
#
#   margin_level capital_intensity_level accelerator_program  market_size_total  \
# 0         High                    High                  No       1.600000e+10
# 1         High                    High                 Yes       8.000000e+09
# 2         High                    High                  No       5.800000e+09
# 3          Low                    High                  No       1.500000e+09
# 4         High                    High                  No       3.080000e+11
#
#   market_size_total_buckets  market_size_addressable  \
# 0                    #NAME?             1.000000e+09
# 1                    #NAME?             4.000000e+08
# 2                    #NAME?             1.200000e+09
# 3                    #NAME?             2.420000e+08
# 4                    #NAME?             2.700000e+08
#
#   market_size_addressable_buckets market_growth_rate  \
# 0                          #NAME?              2.70%
# 1                          #NAME?             38.00%
# 2                          #NAME?             31.40%
# 3                          #NAME?             13.00%
# 4                          #NAME?             44.00%
#
#   market_growth_rate_buckets direct_competitors differentiation_level_quality  \
# 0                     #NAME?                  6                          High
# 1                     #NAME?                 10                          High
# 2                     #NAME?                  7                           Low
# 3                     #NAME?                240                          High
# 4                     #NAME?                 25                          High
#
#   differentiation_level_price how_is_it_10x_better barriers_to_entry  \
# 0                         Low    Similar to others               Low
# 1                         Low    Similar to others              High
# 2                        High    Similar to others               Low
# 3                         Low    Similar to others               Low
# 4                         Low    Similar to others              High
#
#   threat_of_substitute_products has_social_impact has_patents has_users  \
# 0                          High                No         Yes        No
# 1                          High               Yes          No        No
# 2                          High                No          No        No
# 3                          High                No          No        No
# 4                          High                No          No        No
#
#   has_paying_customers  total_revenue total_revenue_brackets  monthly_burn  \
# 0                   No            0.0                 #NAME?       10483.0
# 1                   No            0.0                 #NAME?       40745.0
# 2                   No            0.0                 #NAME?           0.0
# 3                   No            0.0                 #NAME?         564.0
# 4                  Yes          140.0                 #NAME?        2380.0
#
#   prior_rounds_total_amount_raised prior_rounds_total_amount_raised_buckets  \
# 0                              $0                                    #NAME?
# 1                        $659,800                                    #NAME?
# 2                              $0                                    #NAME?
# 3                              $0                                    #NAME?
# 4                              $0                                    #NAME?
#
#    monthly_burn_rate monthly_burn_rate_of_capital_buckets development_phase  \
# 0             1.0000                               #NAME?       Pre-Revenue
# 1             0.0618                               #NAME?       Pre-Revenue
# 2             1.0000                               #NAME?       Pre-Product
# 3             1.0000                               #NAME?       Pre-Revenue
# 4             1.0000                               #NAME?        Pre-Profit
#
#   bio_development_phase has_partnerships  relevant_partners  founders  \
# 0                   NaN               No                0.0       2.0
# 1                   NaN              Yes                2.0       2.0
# 2                   NaN               No                0.0       1.0
# 3                   NaN              Yes                1.0       1.0
# 4                   NaN               No                0.0       4.0
#
#   has_shared_experience has_female_founders has_minority_founders  \
# 0                    No                 Yes                    No
# 1                   Yes                  No                    No
# 2                    No                  No                    No
# 3                    No                  No                    No
# 4                    No                 Yes                    No
#
#   has_famous_founders  unique_universities  employees  relevent_advisors  \
# 0                  No                  3.0        2.0                3.0
# 1                  No                  5.0        4.0                7.0
# 2                  No                  0.0        1.0                0.0
# 3                  No                  1.0        9.0                1.0
# 4                  No                  3.0        8.0                1.0
#
#    notable_investors  spacer founder 1  \
# 0                0.0               NaN
# 1                0.0               NaN
# 2                0.0               NaN
# 3                0.0               NaN
# 4                0.0               NaN
#
#    founder_1_relevant_industry_experience  founder_1_previous_startups  \
# 0                                     9.0                          0.0
# 1                                     1.0                          0.0
# 2                                     0.0                          0.0
# 3                                     0.0                          2.0
# 4                                     0.0                          1.0
#
#    founder_1_exits  founder_1_age founder_1_graduated_from_top_100  \
# 0              0.0           50.0                               No
# 1              0.0           53.0                               No
# 2              0.0           45.0                               No
# 3              0.0           45.0                               No
# 4              0.0           42.0                               No
#
#    spacer founder 2  founder_2_relevant_industry_experience  \
# 0               NaN                                     NaN
# 1               NaN                                    15.0
# 2               NaN                                     NaN
# 3               NaN                                     NaN
# 4               NaN                                    15.0
#
#    founder_2_previous_startups  founder_2_exits  founder_2_age  \
# 0                          NaN              NaN            NaN
# 1                          2.0              2.0           50.0
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          0.0              0.0            NaN
#
#   founder_2_graduated_from_top_100  spacer founder 3  \
# 0                              NaN               NaN
# 1                               No               NaN
# 2                              NaN               NaN
# 3                              NaN               NaN
# 4                               No               NaN
#
#    founder_3_relevant_industry_experience  founder_3_previous_startups  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     0.0                          0.0
#
#    founder_3_exits  founder_3_age founder_3_graduated_from_top_100  \
# 0              NaN            NaN                              NaN
# 1              NaN            NaN                              NaN
# 2              NaN            NaN                              NaN
# 3              NaN            NaN                              NaN
# 4              0.0           42.0                              Yes
#
#    spacer founder 4  founder_4_relevant_industry_experience  \
# 0               NaN                                     NaN
# 1               NaN                                     NaN
# 2               NaN                                     NaN
# 3               NaN                                     NaN
# 4               NaN                                     NaN
#
#    founder_4_previous_startups  founder_4_exits  founder_4_age  \
# 0                          NaN              NaN            NaN
# 1                          NaN              NaN            NaN
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          NaN              NaN            NaN
#
#   founder_4_graduated_from_top_100  spacer founder 5  \
# 0                              NaN               NaN
# 1                              NaN               NaN
# 2                              NaN               NaN
# 3                              NaN               NaN
# 4                              NaN               NaN
#
#    founder_5_relevant_industry_experience  founder_5_previous_startups  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#    founder_5_exits  founder_5_age founder_5_graduated_from_top_100  \
# 0              NaN            NaN                              NaN
# 1              NaN            NaN                              NaN
# 2              NaN            NaN                              NaN
# 3              NaN            NaN                              NaN
# 4              NaN            NaN                              NaN
#
#    spacer founder 6  founder_6_relevant_industry_experience  \
# 0               NaN                                     NaN
# 1               NaN                                     NaN
# 2               NaN                                     NaN
# 3               NaN                                     NaN
# 4               NaN                                     NaN
#
#    founder_6_previous_startups  founder_6_exits  founder_6_age  \
# 0                          NaN              NaN            NaN
# 1                          NaN              NaN            NaN
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          NaN              NaN            NaN
#
#    founder_6_graduated_from_top_100 spacer founder 7  \
# 0                               NaN              NaN
# 1                               NaN              NaN
# 2                               NaN              NaN
# 3                               NaN              NaN
# 4                               NaN              NaN
#
#    founder_7_relevant_industry_experience  founder_7_previous_startups  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#    founder_7_exits  founder_7_age  founder_7_graduated_from_top_100  \
# 0              NaN            NaN                               NaN
# 1              NaN            NaN                               NaN
# 2              NaN            NaN                               NaN
# 3              NaN            NaN                               NaN
# 4              NaN            NaN                               NaN
#
#    spacer founder 8 founder_8_relevant_industry_experience  \
# 0               NaN                                    NaN
# 1               NaN                                    NaN
# 2               NaN                                    NaN
# 3               NaN                                    NaN
# 4               NaN                                    NaN
#
#    founder_8_previous_startups  founder_8_exits  founder_8_age  \
# 0                          NaN              NaN            NaN
# 1                          NaN              NaN            NaN
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          NaN              NaN            NaN
#
#    founder_8_graduated_from_top_100  spacer founder 9  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
#
#    founder_9_relevant_industry_experience founder_9_previous_startups  \
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4                                     NaN                         NaN
#
#    founder_9_exits  founder_9_age  founder_9_graduated_from_top_100  \
# 0              NaN            NaN                               NaN
# 1              NaN            NaN                               NaN
# 2              NaN            NaN                               NaN
# 3              NaN            NaN                               NaN
# 4              NaN            NaN                               NaN
#
#    Unnamed: 122  Unnamed: 123  Unnamed: 124 Unnamed: 125
# 0           NaN           NaN           NaN          NaN
# 1           NaN           NaN           NaN          NaN
# 2           NaN           NaN           NaN          NaN
# 3           NaN           NaN           NaN          NaN
# 4           NaN           NaN           NaN          NaN

# %%
valuation = ratings_data["valuations_combined"]
revenue = ratings_data["total_revenue"]
addressable_market = ratings_data["market_size_addressable"]
total_market = ratings_data["market_size_total"]
market_growth = ratings_data["market_growth_rate"]
burn_rate = ratings_data["monthly_burn_rate"]

# %%
ratings_data.dtypes
# Out:
# writer                                     object
# cik                                       float64
# company                                    object
# date_created                               object
# platform                                   object
# platform_url                               object
# sec_filing_url                             object
# sec_filing_date                            object
# legal_name                                 object
# dba                                        object
# industry                                   object
# tech_sector                                object
# stage                                      object
# series                                     object
# crowdfunding_type_1                        object
# crowdfunding_type_2                        object
# security_type                              object
# rev_share_return_multiple                 float64
# debt_interest_rate                         object
# pre_money_valuation                        object
# valuation_cap                              object
# discount_rate                              object
# valuation_cap_after_discount               object
# valuations_combined                       float64
# valuations_brackets                        object
# revenue_model                              object
# distrubution_model                         object
# business_type                              object
# has_scalable_business_model                object
# margin_level                               object
#                                            ...
# founder_5_age                             float64
# founder_5_graduated_from_top_100           object
# spacer founder 6                          float64
# founder_6_relevant_industry_experience    float64
# founder_6_previous_startups               float64
# founder_6_exits                           float64
# founder_6_age                             float64
# founder_6_graduated_from_top_100          float64
# spacer founder 7                           object
# founder_7_relevant_industry_experience    float64
# founder_7_previous_startups               float64
# founder_7_exits                           float64
# founder_7_age                             float64
# founder_7_graduated_from_top_100          float64
# spacer founder 8                          float64
# founder_8_relevant_industry_experience     object
# founder_8_previous_startups               float64
# founder_8_exits                           float64
# founder_8_age                             float64
# founder_8_graduated_from_top_100          float64
# spacer founder 9                          float64
# founder_9_relevant_industry_experience    float64
# founder_9_previous_startups                object
# founder_9_exits                           float64
# founder_9_age                             float64
# founder_9_graduated_from_top_100          float64
# Unnamed: 122                              float64
# Unnamed: 123                              float64
# Unnamed: 124                              float64
# Unnamed: 125                               object
# Length: 126, dtype: object

# %%
#int(valuation.replace(',', ''))

# %%
ratings_data['total_revenue'].dtypes
# Out:
# dtype('float64')

# %%
rev_valuation_corr = revenue.corr(valuation)
rev_valuation_corr
# Out:
# 0.30149652915059355

# %%
addressable_mkt_valuation_corr = addressable_market.corr(valuation)
addressable_mkt_valuation_corr
# Out:
# 0.03658308245732348

# %%
total_mkt_valuation_corr = total_market.corr(valuation)
total_mkt_valuation_corr
# Out:
# 0.03187805538237101

# %%
burn_rate_valuation_corr = burn_rate.corr(valuation)
burn_rate_valuation_corr
# Out:
# -0.19354287430063563

# %%
age = ratings_data['founder_1_age']
age_valuation_corr = age.corr(valuation)
age_valuation_corr
# Out:
# 0.12914343916991264

# %%
rev_burn_corr = revenue.corr(burn_rate)
rev_burn_corr
# Out:
# -0.11780389549123092

# %%
ratings_data['revenue_multiple'] = ratings_data['valuations_combined'] / ratings_data['total_revenue']

# %%
ratings_data['revenue_multiple']
# Out:
# 0               inf
# 1               inf
# 2               inf
# 3               inf
# 4      3.428571e+04
# 5               inf
# 6               inf
# 7      3.663717e+00
# 8               inf
# 9      1.391018e+01
# 10     6.558859e+00
# 11              inf
# 12     2.806470e+00
# 13              inf
# 14     6.536268e+00
# 15     2.907893e+01
# 16     1.114305e+01
# 17     9.519277e+01
# 18     1.279818e+02
# 19              inf
# 20     2.709831e+00
# 21              inf
# 22              inf
# 23     7.295942e+01
# 24              inf
# 25     8.585174e+00
# 26     2.061098e+01
# 27              inf
# 28     3.777798e+01
# 29     1.686547e+02
#            ...
# 296             NaN
# 297             NaN
# 298             NaN
# 299             NaN
# 300             NaN
# 301             NaN
# 302             NaN
# 303             NaN
# 304             NaN
# 305             NaN
# 306             NaN
# 307             NaN
# 308             NaN
# 309             NaN
# 310             NaN
# 311             NaN
# 312             NaN
# 313             NaN
# 314             NaN
# 315             NaN
# 316             NaN
# 317             NaN
# 318             NaN
# 319             NaN
# 320             NaN
# 321             NaN
# 322             NaN
# 323    0.000000e+00
# 324    0.000000e+00
# 325    0.000000e+00
# Name: revenue_multiple, Length: 326, dtype: float64

# %%
ratings_data['revenue_multiple'].replace(np.inf, 0, inplace=True)
ratings_data['revenue_multiple']
# Out:
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4      34285.714286
# 5          0.000000
# 6          0.000000
# 7          3.663717
# 8          0.000000
# 9         13.910179
# 10         6.558859
# 11         0.000000
# 12         2.806470
# 13         0.000000
# 14         6.536268
# 15        29.078935
# 16        11.143045
# 17        95.192765
# 18       127.981798
# 19         0.000000
# 20         2.709831
# 21         0.000000
# 22         0.000000
# 23        72.959416
# 24         0.000000
# 25         8.585174
# 26        20.610985
# 27         0.000000
# 28        37.777983
# 29       168.654667
#            ...
# 296             NaN
# 297             NaN
# 298             NaN
# 299             NaN
# 300             NaN
# 301             NaN
# 302             NaN
# 303             NaN
# 304             NaN
# 305             NaN
# 306             NaN
# 307             NaN
# 308             NaN
# 309             NaN
# 310             NaN
# 311             NaN
# 312             NaN
# 313             NaN
# 314             NaN
# 315             NaN
# 316             NaN
# 317             NaN
# 318             NaN
# 319             NaN
# 320             NaN
# 321             NaN
# 322             NaN
# 323        0.000000
# 324        0.000000
# 325        0.000000
# Name: revenue_multiple, Length: 326, dtype: float64

# %%
ratings_data.head()
# Out:
#    writer        cik                    company     date_created     platform  \
# 0  Olivia  1778006.0          Weeds Never Sleep   7/3/2019 11:08     TruCrowd
# 1  Olivia  1720258.0        StorEn Technologies    7/4/2019 8:55  StartEngine
# 2  Olivia  1753677.0  Palouse Ag-Drone Services  7/11/2019 14:41     Razitall
# 3  Olivia  1765620.0  El Tinieblo International  7/13/2019 10:14  StartEngine
# 4  Olivia  1777377.0                  Spero CBD  7/16/2019 10:34  StartEngine
#
#                                         platform_url  \
# 0  https://us.trucrowd.com/equity/offer-summary/W...
# 1    https://www.startengine.com/storen-technologies
# 2  https://www.razitall.com/pitch/the-ag-drone-an...
# 3  https://www.startengine.com/el-tinieblo-intern...
# 4              https://www.startengine.com/spero-cbd
#
#                                       sec_filing_url sec_filing_date  \
# 0  https://disclosurequest.com/form/weeds-never-s...       6/25/2019
# 1  https://www.sec.gov/Archives/edgar/data/172025...        7/3/2019
# 2  https://disclosurequest.com/form/palouse-ag-dr...       10/4/2018
# 3  https://www.sec.gov/Archives/edgar/data/176562...       7/12/2019
# 4  https://www.sec.gov/Archives/edgar/data/177737...       7/15/2019
#
#                          legal_name                          dba  \
# 0             Weeds Never Sleep LLC  Weeds Never Sleep or HotZot
# 1               StorEn Technologies          StorEn Technologies
# 2     Palouse Ag-Drone Services LLC                 The Ag-Drone
# 3  El Tinieblo International, Inc.     El Tinieblo International
# 4                    Noble Naturals                    Spero CBD
#
#            industry tech_sector  stage    series crowdfunding_type_1  \
# 0    Consumer Goods    AgriTech  Early  Pre-Seed               RegCF
# 1    Consumer Goods   CleanTech  Early  Pre-Seed               RegCF
# 2           Farming    AgriTech  Early  Pre-Seed               RegCF
# 3    Wine & Spirits    Non-Tech  Early  Pre-Seed               RegCF
# 4  Cannabis and CBD    Non-Tech  Early  Pre-Seed               RegCF
#
#   crowdfunding_type_2     security_type  rev_share_return_multiple  \
# 0                 NaN              SAFE                        NaN
# 1                 NaN   Equity - Common                        NaN
# 2                 NaN             CAFES                        NaN
# 3                 NaN   Equity - Common                        NaN
# 4                 NaN  Convertible Note                        NaN
#
#   debt_interest_rate pre_money_valuation valuation_cap discount_rate  \
# 0                NaN                 NaN   $2,500,000             0%
# 1                NaN        $28,100,000            NaN           NaN
# 2                NaN                 NaN     $400,000             0%
# 3                NaN         $7,500,000            NaN           NaN
# 4                NaN                 NaN   $6,000,000            20%
#
#   valuation_cap_after_discount  valuations_combined valuations_brackets  \
# 0                  $2,500,000             2500000.0              #NAME?
# 1                          NaN           28100000.0              #NAME?
# 2                    $400,000              400000.0              #NAME?
# 3                          NaN            7500000.0              #NAME?
# 4                  $4,800,000             4800000.0              #NAME?
#
#    revenue_model distrubution_model business_type has_scalable_business_model  \
# 0  Transactional                B2C    Life Style                          No
# 1  Transactional                B2C    Life Style                          No
# 2  Transactional                B2C    Life Style                          No
# 3  Transactional              B2B2C    Life Style                          No
# 4  Transactional                B2C    Life Style                         Yes
#
#   margin_level capital_intensity_level accelerator_program  market_size_total  \
# 0         High                    High                  No       1.600000e+10
# 1         High                    High                 Yes       8.000000e+09
# 2         High                    High                  No       5.800000e+09
# 3          Low                    High                  No       1.500000e+09
# 4         High                    High                  No       3.080000e+11
#
#   market_size_total_buckets  market_size_addressable  \
# 0                    #NAME?             1.000000e+09
# 1                    #NAME?             4.000000e+08
# 2                    #NAME?             1.200000e+09
# 3                    #NAME?             2.420000e+08
# 4                    #NAME?             2.700000e+08
#
#   market_size_addressable_buckets market_growth_rate  \
# 0                          #NAME?              2.70%
# 1                          #NAME?             38.00%
# 2                          #NAME?             31.40%
# 3                          #NAME?             13.00%
# 4                          #NAME?             44.00%
#
#   market_growth_rate_buckets direct_competitors differentiation_level_quality  \
# 0                     #NAME?                  6                          High
# 1                     #NAME?                 10                          High
# 2                     #NAME?                  7                           Low
# 3                     #NAME?                240                          High
# 4                     #NAME?                 25                          High
#
#   differentiation_level_price how_is_it_10x_better barriers_to_entry  \
# 0                         Low    Similar to others               Low
# 1                         Low    Similar to others              High
# 2                        High    Similar to others               Low
# 3                         Low    Similar to others               Low
# 4                         Low    Similar to others              High
#
#   threat_of_substitute_products has_social_impact has_patents has_users  \
# 0                          High                No         Yes        No
# 1                          High               Yes          No        No
# 2                          High                No          No        No
# 3                          High                No          No        No
# 4                          High                No          No        No
#
#   has_paying_customers  total_revenue total_revenue_brackets  monthly_burn  \
# 0                   No            0.0                 #NAME?       10483.0
# 1                   No            0.0                 #NAME?       40745.0
# 2                   No            0.0                 #NAME?           0.0
# 3                   No            0.0                 #NAME?         564.0
# 4                  Yes          140.0                 #NAME?        2380.0
#
#   prior_rounds_total_amount_raised prior_rounds_total_amount_raised_buckets  \
# 0                              $0                                    #NAME?
# 1                        $659,800                                    #NAME?
# 2                              $0                                    #NAME?
# 3                              $0                                    #NAME?
# 4                              $0                                    #NAME?
#
#    monthly_burn_rate monthly_burn_rate_of_capital_buckets development_phase  \
# 0             1.0000                               #NAME?       Pre-Revenue
# 1             0.0618                               #NAME?       Pre-Revenue
# 2             1.0000                               #NAME?       Pre-Product
# 3             1.0000                               #NAME?       Pre-Revenue
# 4             1.0000                               #NAME?        Pre-Profit
#
#   bio_development_phase has_partnerships  relevant_partners  founders  \
# 0                   NaN               No                0.0       2.0
# 1                   NaN              Yes                2.0       2.0
# 2                   NaN               No                0.0       1.0
# 3                   NaN              Yes                1.0       1.0
# 4                   NaN               No                0.0       4.0
#
#   has_shared_experience has_female_founders has_minority_founders  \
# 0                    No                 Yes                    No
# 1                   Yes                  No                    No
# 2                    No                  No                    No
# 3                    No                  No                    No
# 4                    No                 Yes                    No
#
#   has_famous_founders  unique_universities  employees  relevent_advisors  \
# 0                  No                  3.0        2.0                3.0
# 1                  No                  5.0        4.0                7.0
# 2                  No                  0.0        1.0                0.0
# 3                  No                  1.0        9.0                1.0
# 4                  No                  3.0        8.0                1.0
#
#    notable_investors  spacer founder 1  \
# 0                0.0               NaN
# 1                0.0               NaN
# 2                0.0               NaN
# 3                0.0               NaN
# 4                0.0               NaN
#
#    founder_1_relevant_industry_experience  founder_1_previous_startups  \
# 0                                     9.0                          0.0
# 1                                     1.0                          0.0
# 2                                     0.0                          0.0
# 3                                     0.0                          2.0
# 4                                     0.0                          1.0
#
#    founder_1_exits  founder_1_age founder_1_graduated_from_top_100  \
# 0              0.0           50.0                               No
# 1              0.0           53.0                               No
# 2              0.0           45.0                               No
# 3              0.0           45.0                               No
# 4              0.0           42.0                               No
#
#    spacer founder 2  founder_2_relevant_industry_experience  \
# 0               NaN                                     NaN
# 1               NaN                                    15.0
# 2               NaN                                     NaN
# 3               NaN                                     NaN
# 4               NaN                                    15.0
#
#    founder_2_previous_startups  founder_2_exits  founder_2_age  \
# 0                          NaN              NaN            NaN
# 1                          2.0              2.0           50.0
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          0.0              0.0            NaN
#
#   founder_2_graduated_from_top_100  spacer founder 3  \
# 0                              NaN               NaN
# 1                               No               NaN
# 2                              NaN               NaN
# 3                              NaN               NaN
# 4                               No               NaN
#
#    founder_3_relevant_industry_experience  founder_3_previous_startups  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     0.0                          0.0
#
#    founder_3_exits  founder_3_age founder_3_graduated_from_top_100  \
# 0              NaN            NaN                              NaN
# 1              NaN            NaN                              NaN
# 2              NaN            NaN                              NaN
# 3              NaN            NaN                              NaN
# 4              0.0           42.0                              Yes
#
#    spacer founder 4  founder_4_relevant_industry_experience  \
# 0               NaN                                     NaN
# 1               NaN                                     NaN
# 2               NaN                                     NaN
# 3               NaN                                     NaN
# 4               NaN                                     NaN
#
#    founder_4_previous_startups  founder_4_exits  founder_4_age  \
# 0                          NaN              NaN            NaN
# 1                          NaN              NaN            NaN
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          NaN              NaN            NaN
#
#   founder_4_graduated_from_top_100  spacer founder 5  \
# 0                              NaN               NaN
# 1                              NaN               NaN
# 2                              NaN               NaN
# 3                              NaN               NaN
# 4                              NaN               NaN
#
#    founder_5_relevant_industry_experience  founder_5_previous_startups  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#    founder_5_exits  founder_5_age founder_5_graduated_from_top_100  \
# 0              NaN            NaN                              NaN
# 1              NaN            NaN                              NaN
# 2              NaN            NaN                              NaN
# 3              NaN            NaN                              NaN
# 4              NaN            NaN                              NaN
#
#    spacer founder 6  founder_6_relevant_industry_experience  \
# 0               NaN                                     NaN
# 1               NaN                                     NaN
# 2               NaN                                     NaN
# 3               NaN                                     NaN
# 4               NaN                                     NaN
#
#    founder_6_previous_startups  founder_6_exits  founder_6_age  \
# 0                          NaN              NaN            NaN
# 1                          NaN              NaN            NaN
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          NaN              NaN            NaN
#
#    founder_6_graduated_from_top_100 spacer founder 7  \
# 0                               NaN              NaN
# 1                               NaN              NaN
# 2                               NaN              NaN
# 3                               NaN              NaN
# 4                               NaN              NaN
#
#    founder_7_relevant_industry_experience  founder_7_previous_startups  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#    founder_7_exits  founder_7_age  founder_7_graduated_from_top_100  \
# 0              NaN            NaN                               NaN
# 1              NaN            NaN                               NaN
# 2              NaN            NaN                               NaN
# 3              NaN            NaN                               NaN
# 4              NaN            NaN                               NaN
#
#    spacer founder 8 founder_8_relevant_industry_experience  \
# 0               NaN                                    NaN
# 1               NaN                                    NaN
# 2               NaN                                    NaN
# 3               NaN                                    NaN
# 4               NaN                                    NaN
#
#    founder_8_previous_startups  founder_8_exits  founder_8_age  \
# 0                          NaN              NaN            NaN
# 1                          NaN              NaN            NaN
# 2                          NaN              NaN            NaN
# 3                          NaN              NaN            NaN
# 4                          NaN              NaN            NaN
#
#    founder_8_graduated_from_top_100  spacer founder 9  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
#
#    founder_9_relevant_industry_experience founder_9_previous_startups  \
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4                                     NaN                         NaN
#
#    founder_9_exits  founder_9_age  founder_9_graduated_from_top_100  \
# 0              NaN            NaN                               NaN
# 1              NaN            NaN                               NaN
# 2              NaN            NaN                               NaN
# 3              NaN            NaN                               NaN
# 4              NaN            NaN                               NaN
#
#    Unnamed: 122  Unnamed: 123  Unnamed: 124 Unnamed: 125  revenue_multiple
# 0           NaN           NaN           NaN          NaN          0.000000
# 1           NaN           NaN           NaN          NaN          0.000000
# 2           NaN           NaN           NaN          NaN          0.000000
# 3           NaN           NaN           NaN          NaN          0.000000
# 4           NaN           NaN           NaN          NaN      34285.714286

# %%
revenue_multiple = ratings_data['revenue_multiple']

# %%
rev_multiple_rev_corr = revenue_multiple.corr(revenue)
rev_multiple_rev_corr
# Out:
# -0.0261587493874618

# %%
rev_multiple_burn_corr = revenue_multiple.corr(burn_rate)
rev_multiple_burn_corr
# Out:
# 0.07695779110269875

# %%
rev_multiple_add_mkt_corr = revenue_multiple.corr(addressable_market)
rev_multiple_add_mkt_corr
# Out:
# -0.008749647080233807

# %%
rev_multiple_age_corr = revenue_multiple.corr(age)
rev_multiple_age_corr
# Out:
# -0.013492164848768388

# %%
ratings_data['revenue']
